# %%
# implementasi bubble sort
def bubble_sort(arr):
  n = len(arr)
  for i in range(n-1):
    for j in range(n-i-1):
      if arr[j] > arr[j+1]:
          arr[j], arr[j+1] = arr[j+1], arr[j]
  return arr

data =[64, 34, 25,12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah bubble sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort: [11, 12, 22, 25, 34, 64, 90]

# %%
# implementasi selection sort
def selection_sort(arr):
  n = len(arr)
  for i in range(n-1):
    min_index = i
    for j in range(i+1, n):
      if arr[j] < arr[min_index]:
        min_index = j
    arr[i], arr[min_index] = arr[min_index], arr[i]
  return arr

# Contoh
data = [64, 34, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah bubble sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah bubble sort: [11, 12, 22, 25, 64]

# %%
# implementasi insertion sort
def insertion_sort(arr):
  n = len(arr)
  for i in range(1, n):
      key = arr[i]
      j = i - 1
      while j >= 0 and key < arr[j]:
        arr[j+i] = key
  return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah bubble sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11]
# Data setelah bubble sort: [11, 12, 22, 25, 34, 64]

# %%
# marge short
def marge_short (arr):
  if len(arr) > 1:
    mid = len(arr) //2
    left_half = arr[:mid:]
    right_half = arr[:mid:]

    marge_short(left_half)
    marge_short(right_half)

    i = j = k = 0
    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[j]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[j]
        j += 1
        k += 1

      while i < len(left_half):
        arr[k] = left_half[i]
        i += 1
        k += 1

      while j < len(right_half):
        arr[k] = right_half[j]
        j += 1
        k += 1
      return arr

      # Contoh penggunaan
data = [64, 34, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah bubble sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11]
# Data setelah bubble sort: [11, 12, 22, 25, 34, 64]

# %%
# Implementasi Quick Short
def quick_sort(arr):
  if len(arr) <= 1:
    return arr

  pivot = arr(len(arr) // 2)
  left = [x for x in  arr if x  < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]
  return quick_sort(left) + middle + quick_sort(right)

 # Contoh penggunaan
data = [64, 34, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah bubble sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11]
# Data setelah bubble sort: [11, 12, 22, 25, 34, 64]

# %%
# Tugas (sistem manajemen data pengguna)
def bubble_sort(arr, key):
  n = len(arr)
  for i in range(n-1):
    for j in range(n-i-1):
      # Compare based on the specified key
      if arr[j][key] > arr[j+1][key]:
          arr[j], arr[j+1] = arr[j+1], arr[j]
  return arr

# Data pelanggan
pelanggan = [
    {"nama": "Casto", "umur": 18, "total_belanja": 150000},
    {"nama": "Mei", "umur": 20, "total_belanja": 250000},
    {"nama": "Sparkle", "umur": 17, "total_belanja": 100000},
    {"nama": "Himeko", "umur": 25, "total_belanja": 200000}
]

hasil = bubble_sort(pelanggan, "nama")

print("Data setelah diurutkan berdasarkan nama (A-Z):")
for p in hasil:
    print(p)
# Out:
# Data setelah diurutkan berdasarkan nama (A-Z):
# {'nama': 'Casto', 'umur': 18, 'total_belanja': 150000}
# {'nama': 'Himeko', 'umur': 25, 'total_belanja': 200000}
# {'nama': 'Mei', 'umur': 20, 'total_belanja': 250000}
# {'nama': 'Sparkle', 'umur': 17, 'total_belanja': 100000}
